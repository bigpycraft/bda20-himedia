# %%
import os
from os.path import exists

import requests  
from bs4 import BeautifulSoup 

from urllib.request import urlopen

import pandas as pd
import re

# %% [markdown]
# # <font color='#da5e3c'>웹 크롤링</font>
#
# ## <font color='#e87a54'>웹 페이지에서 필요한 정보 파싱</font>
# - The 50 Best Sandwiches in Chicago
# - 메인페이지의 TOP50 리스트 정보 가져오기
# - 각각에 연결된 상세 정보 가져오기
#
# > - 과제1 : 메인페이지 정보 크롤링 - 랭킹, 카페명, 메뉴명, 상세페이지링커
# > - 과제2 : 상세페이지 정보 크롤링 - 가격, 주소, 전화번호, 홈페이지정보
# > - 과제3 : 과제1, 과제2 정보를 모두 포함하여 파일로 저장하기

# %% [markdown]
# ### <font color='#fc9d6f'>과제1: 메인페이지 정보 크롤링</font>
#
# - 랭킹
# - 카페명
# - 메뉴명
# - 상세페이지 링크

# %% [markdown]
# ### 하나의 데이터(1위, BLT)로 구축

# %%
url = 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'

html = urlopen(url)
soup = BeautifulSoup(html, "lxml")

    # 데이터가 잘 불러졌는지 title로 확인
soup.title
# Out:
# <title>
#   The 50 Best Sandwiches in Chicago |
#   Chicago magazine
#       |  November 2012
#     </title>

# %%
# 모든 샌드위치 목록을 포함하는 div(class = content post)
# 한 개의 샌드위치 정보를 가진  div(class = sammy)

content_tag = soup.find('div', 'content post')
sammy_tags  = content_tag.find_all('div', 'sammy')

len(sammy_tags)  # The "50" Best Sandwiches in Chicago  -> length: 50
# Out:
# 50

# %%
# div "sammy" 안에서 개별적으로 가져올 수 있는 데이터 확인

sammy = sammy_tags[0]

sammy

    # sammyRank      -> Ranking
    # sammyListing   ->  Menu & Cafe, Link
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
# div "sammyRank"를 통해 랭킹 불러오기(int형으로 변환)

tmp = sammy.find('div', 'sammyRank')
rank = int(tmp.get_text().strip())

rank
# Out:
# 1

# %%
# <div "sammyListing"> / <a - 메뉴, 카페, 더보기> / <b - 메뉴>

listing = sammy.find('div', 'sammyListing')
tmp = listing.find('a')

# ------------------------------------------------------------ #
    # menu: <b> 태그 text
menu = (tmp.find('b')).get_text().strip()

# ------------------------------------------------------------ #
    # link = url + tmp(<a> 태그) 안의 href 값
link = "http://www.chicagomag.com" + tmp['href']

# ------------------------------------------------------------ #
    # cafe: <a> 태그 안의 값을 가져온 다음, 
    # 불필요한 데이터(문자열, menu) 제거
cafe = tmp.get_text().strip()

cafe = cafe.replace("\r", "")
cafe = cafe.replace("\n", "")
cafe = cafe.replace("Read more", "")
cafe = cafe.replace(menu, "")

cafe = cafe.strip()
# ------------------------------------------------------------ #

print(menu)
print(cafe)
print(link)
# Out:
# BLT
# Old Oak Tap
# http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/

# %% [markdown]
# ### 모듈화 하여 50개 샌드위치 데이터 저장

# %%
def crawl_ChiSdw():
    Rank = []; Menu = []
    Cafe = []; Link = []
    
    url = 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
    html = urlopen(url)
    soup = BeautifulSoup(html, "lxml")
    
    content_tag = soup.find('div', 'content post')
    sammy_tags  = content_tag.find_all('div', 'sammy')
    
    
    for sammy in sammy_tags:

        tmp = sammy.find('div', 'sammyRank')
        rank = int(tmp.get_text().strip())

        listing = sammy.find('div', 'sammyListing')
        tmp = listing.find('a')
        
        # 메뉴 ======================================== #
        menu = (tmp.find('b')).get_text().strip()
        
        # 링크 ======================================== #
        link = tmp['href']
        link = link.replace('http://www.chicagomag.com', '')
        link = "http://www.chicagomag.com" + link
        
        # 카페 ======================================== #
        cafe = tmp.get_text().strip()
        
        cafe = cafe.replace("\r", "")
        cafe = cafe.replace("\n", "")
        cafe = cafe.replace("Read more", "")
        cafe = cafe.replace(menu, "")
        
        cafe = cafe.strip()
        
        
        Rank.append(rank); Cafe.append(cafe)
        Menu.append(menu); Link.append(link)
    
    data = {'순위'  : Rank, '카페명': Cafe,
            '메뉴명': Menu, '링크'  : Link }
    
    returnDF = pd.DataFrame(data)
    
    return returnDF

# %%
df = crawl_ChiSdw()
df.set_index('순위', inplace = True)

df.head(10)
# Out:
#                                 카페명  \
# 순위
# 1                       Old Oak Tap
# 2                         Au Cheval
# 3                              Xoco
# 4                         Al’s Deli
# 5            Publican Quality Meats
# 6   Hendrickx Belgian Bread Crafter
# 7                            Acadia
# 8                 Birchwood Kitchen
# 9                    Cemitas Puebla
# 10                             Nana
#
#                                                메뉴명  \
# 순위
# 1                                              BLT
# 2                                    Fried Bologna
# 3                                Woodland Mushroom
# 4                                       Roast Beef
# 5                                             PB&L
# 6                      Belgian Chicken Curry Salad
# 7                                     Lobster Roll
# 8                              Smoked Salmon Salad
# 9                                  Atomica Cemitas
# 10  Grilled Laughing Bird Shrimp and Fried Po’ Boy
#
#                                                    링크
# 순위
# 1   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 5   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 6   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 7   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 8   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 9   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 10  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
# 1차 저장
df.to_csv('data/chicago_sandwiches_2012.csv', sep = ',', encoding = 'UTF-8')

# %% [markdown]
# ### <font color='#fc9d6f'>과제2: 상세페이지 정보 크롤링</font>
#
# - 가격
# - 주소
# - 전화번호
# - 홈페이지 정보

# %%
url_1 = df['링크'][6]

url_1
# Out:
# 'http://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/'

# %%
html = urlopen(url_1)
soup = BeautifulSoup(html, 'lxml')

soup.title
# Out:
# <title>
#   6. Hendrickx Belgian Bread Crafter Belgian Chicken Curry Salad |
#   Chicago magazine
#       |  November 2012
#     </title>

# %%
# <p "addy" - 가격, 주소, 홈페이지 링크> / <a - 홈페이지 링크>

p_tag = soup.find('p', 'addy')

addy = p_tag.get_text().strip()

    # 홈페이지 링크
    
if p_tag.find('a') is not None:
    tmp = p_tag.find('a')
    homepage = tmp['href']
else:
    homepage = "-"

homepage
# Out:
# '-'

# %% [markdown]
# # 주소 정규식 모르겠어요ㅠㅠ

# %%
# price : '$00.00'

re_price = re.search('\$\d{1,2}\.\d{0,2}[ .]?', addy)
if re_price is not None:
     price = re_price.group().strip()
else: 
     pass

# %%
# phone : 000-000-0000

re_phone = re.search('\d{3}[ -.]?\d{3}[ -.]?\d{4}', addy)
if re_phone is not None:
     phone = re_phone.group()
else:
     pass

# %%
# addr: replace(price, ''); replace(phone, ''); replace(removal, '')

    # <p "addy"> 에서 홈페이지 제거 용도
removal = homepage.replace('http://', '')
removal = removal.replace('www.', '')
removal = removal.replace('/', '').strip()
      
    # re_addr: addy에서 주소, 금액, 홈페이지 삭제
re_addr = addy.replace(phone, '')
re_addr = re_addr.replace(price, '')
re_addr = re_addr.replace(removal, '')

if re_addr is not None:
    addr = re_addr.replace(',', '').strip()
else:
    pass

# %%
phone
# Out:
# '312-649-6717'

# %%
addr
# Out:
# '100 E. Walton St.'

# %%
price
# Out:
# '$7.25.'

# %%
homepage
# Out:
# '-'

# %% [markdown]
# ### 모듈화 하여 상세페이지들 합치기

# %%
from tqdm import tqdm_notebook

# %%
df
# Out:
#                                 카페명  \
# 순위
# 1                       Old Oak Tap
# 2                         Au Cheval
# 3                              Xoco
# 4                         Al’s Deli
# 5            Publican Quality Meats
# 6   Hendrickx Belgian Bread Crafter
# 7                            Acadia
# 8                 Birchwood Kitchen
# 9                    Cemitas Puebla
# 10                             Nana
# 11                        Lula Cafe
# 12                       Ricobene’s
# 13                     Frog n Snail
# 14                 Crosby’s Kitchen
# 15                  Longman & Eagle
# 16                             Bari
# 17                          Manny’s
# 18                           Eggy’s
# 19                    Old Jerusalem
# 20             Mindy’s HotChocolate
# 21              Olga’s Delicatessen
# 22     Dawali Mediterranean Kitchen
# 23                        Big Jones
# 24                          La Pane
# 25                         Pastoral
# 26                       Max’s Deli
# 27             Lucky’s Sandwich Co.
# 28                  City Provisions
# 29             Papa’s Cache Sabroso
# 30            Bavette’s Bar & Boeuf
# 31                 Hannah’s Bretzel
# 32                     La Fournette
# 33                   Paramount Room
# 34             Melt Sandwich Shoppe
# 35           Floriole Cafe & Bakery
# 36             First Slice Pie Café
# 37                          Troquet
# 38                       Grahamwich
# 39                   Saigon Sisters
# 40                   Rosalia’s Deli
# 41                   Z&H MarketCafe
# 42       Market House on the Square
# 43             Elaine’s Coffee Call
# 44      Marion Street Cheese Market
# 45                         Cafecito
# 46                         Chickpea
# 47           The Goddess and Grocer
# 48                          Zenwich
# 49                  Toni Patisserie
# 50                  Phoebe’s Bakery
#
#                                                메뉴명  \
# 순위
# 1                                              BLT
# 2                                    Fried Bologna
# 3                                Woodland Mushroom
# 4                                       Roast Beef
# 5                                             PB&L
# 6                      Belgian Chicken Curry Salad
# 7                                     Lobster Roll
# 8                              Smoked Salmon Salad
# 9                                  Atomica Cemitas
# 10  Grilled Laughing Bird Shrimp and Fried Po’ Boy
# 11                         Ham and Raclette Panino
# 12                                   Breaded Steak
# 13                                     The Hawkeye
# 14                                     Chicken Dip
# 15                            Wild Boar Sloppy Joe
# 16                                    Meatball Sub
# 17                                     Corned Beef
# 18                                     Turkey Club
# 19                                         Falafel
# 20                                       Crab Cake
# 21                               Chicken Schnitzel
# 22                                        Shawarma
# 23                         Toasted Pimiento Cheese
# 24                               Vegetarian Panino
# 25                                     Cali Chèvre
# 26                                        Pastrami
# 27                                       The Fredo
# 28                                      Smoked Ham
# 29                                        Jibarito
# 30                                Shaved Prime Rib
# 31                 Serrano Ham and Manchego Cheese
# 32                                      Tuna Salad
# 33                                Paramount Reuben
# 34                                    The Istanbul
# 35                                          B.A.D.
# 36                      Duck Confit and Mozzarella
# 37                                 Croque Monsieur
# 38                                  Green Garbanzo
# 39                                   The Hen House
# 40                                  Tuscan Chicken
# 41                                       The Marty
# 42                                       Whitefish
# 43          Oat Bread, Pecan Butter, and Fruit Jam
# 44                                Cauliflower Melt
# 45                                          Cubana
# 46                                           Kufta
# 47                              Debbie’s Egg Salad
# 48                                      Beef Curry
# 49                                   Le Végétarien
# 50                                      The Gatsby
#
#                                                    링크
# 순위
# 1   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 2   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 3   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 4   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 5   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 6   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 7   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 8   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 9   http://www.chicagomag.com/Chicago-Magazine/Nov...
# 10  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 11  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 12  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 13  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 14  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 15  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 16  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 17  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 18  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 19  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 20  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 21  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 22  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 23  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 24  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 25  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 26  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 27  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 28  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 29  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 30  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 31  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 32  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 33  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 34  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 35  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 36  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 37  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 38  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 39  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 40  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 41  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 42  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 43  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 44  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 45  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 46  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 47  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 48  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 49  http://www.chicagomag.com/Chicago-Magazine/Nov...
# 50  http://www.chicagomag.com/Chicago-Magazine/Nov...

# %%
def ChiSdw_detail(df):
    Price = []; Address = []
    Phone = []; Hompage = []
    
    for link in tqdm_notebook(df['링크']):
        html = urlopen(link)
        soup = BeautifulSoup(html, 'lxml')
        
        p_tag = soup.find('p', 'addy')

        addy = p_tag.get_text().strip()

        # 홈페이지 링크 =============================== #
        if p_tag.find('a') is not None:
            tmp = p_tag.find('a')
            homepage = tmp['href']
        else:
            homepage = "-"
        
        # price : '$00.00' ============================ #
        re_price = re.search('\$\d{1,2}\.\d{0,2}[ .]?', addy)
        if re_price is not None:
             price = re_price.group().strip()
        else: 
             pass
        
        # phone : '000-000-0000' ====================== #
        re_phone = re.search('\d{3}[ -.]?\d{3}[ -.]?\d{4}', addy)
        if re_phone is not None:
             phone = re_phone.group()
        else:
             pass
        
        # addr: 정규식으로 하고 싶은데 안 돼요 ======== #
        removal = homepage.replace('http://', '')
        removal = removal.replace('www.', '')
        removal = removal.replace('/', '').strip()

        re_addr = addy.replace(phone, '')
        re_addr = re_addr.replace(price, '')
        re_addr = re_addr.replace(removal, '')

        if re_addr is not None:
            addr = re_addr.replace(',', '').strip()
        else:
            pass
    
        Price.append(price)
        Phone.append(phone)
        Address.append(addr)
        Hompage.append(homepage)
        
    df['가격'] = Price
    df['주소'] = Address
    df['전화번호'] = Phone
    df['홈페이지'] = Hompage
    
    print('저녁도 못 먹었지만.. 결국.. 뚜쉬,, 내가해냄ㅠ')
    
    return df

# %%
result_df = ChiSdw_detail(df)
# Out:
# c:\users\samsung\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# 저녁도 못 먹었지만.. 결국.. 뚜쉬,, 내가해냄ㅠ

# %%
result_df
# Out:
#                                 카페명  \
# 순위
# 1                       Old Oak Tap
# 2                         Au Cheval
# 3                              Xoco
# 4                         Al’s Deli
# 5            Publican Quality Meats
# 6   Hendrickx Belgian Bread Crafter
# 7                            Acadia
# 8                 Birchwood Kitchen
# 9                    Cemitas Puebla
# 10                             Nana
# 11                        Lula Cafe
# 12                       Ricobene’s
# 13                     Frog n Snail
# 14                 Crosby’s Kitchen
# 15                  Longman & Eagle
# 16                             Bari
# 17                          Manny’s
# 18                           Eggy’s
# 19                    Old Jerusalem
# 20             Mindy’s HotChocolate
# 21              Olga’s Delicatessen
# 22     Dawali Mediterranean Kitchen
# 23                        Big Jones
# 24                          La Pane
# 25                         Pastoral
# 11                               2537 N. Kedzie Blvd.  773-489-9554
# 12                                 Multiple locations  773-489-9554
# 13                                   3124 N. Broadway  773-661-9166
# 14                             3455 N. Southport Ave.  773-883-2525
# 15                                2657 N. Kedzie Ave.  773-276-7110
# 16                                 1120 W. Grand Ave.  312-666-0730
# 17                              1141 S. Jefferson St.  312-939-2855
# 18                                  333 E. Benton Pl.  773-234-3449
# 19                                  1411 N. Wells St.  312-944-0459
# 20                                 1747 N. Damen Ave.  773-489-1747
# 21                            3209 W. Irving Park Rd.  773-539-8038
# 22                                 Multiple locations  773-539-8038
# 23                                  5347 N. Clark St.  773-275-5725
# 24                            2954 W. Irving Park Rd.  773-539-5321
# 25                                 Multiple locations  773-539-5321
# 26                191 Skokie Valley Rd. Highland Park  847-831-0600
# 27                                 Multiple locations  847-831-0600
# 28                                1818 W. Wilson Ave.  773-293-2489
# 29                               2517 W. Division St.  773-862-8313
# 30                                  218 W. Kinzie St.  312-624-8154
# 31                                 Multiple locations  312-624-8154
# 32                                  1547 N. Wells St.  312-624-9430
# 33                              415 N. Milwaukee Ave.  312-829-6300
# 34                                 1840 N. Damen Ave.  773-681-9914
# 35                               1220 W. Webster Ave.  773-883-1313
# 36                               5357 N. Ashland Ave.  773-275-4297
# 37                              1834 W. Montrose Ave.  773-334-5664
# 38                                   615 N. State St.  312-265-0434
# 39                                 Multiple locations  312-265-0434
# 40                           241 N. York Rd. Elmhurst  630-516-3354
# 41                                   1323 E. 57th St.  773-538-7372
# 42                        655 Forest Ave. Lake Forest  847-234-8800
# 43  Hotel Lincoln 1816 N. Clark St.  jdvhotels.com...  312-254-4665
# 44                         100 S. Marion St. Oak Park  708-725-7200
# 45                               26 E. Congress Pkwy.  312-922-2233
# 46                               2018 W. Chicago Ave.  773-384-9930
# 47                                 25 E. Delaware Pl.  312-896-2600
# 48                           416 N. York St. Elmhurst  630-359-5234
# 49                               65 E. Washington St.  312-726-2020
# 50                                   3351 N. Broadway  773-868-4000
#
#                                                홈페이지
# 순위
# 1                      http://www.theoldoaktap.com/
# 2                       http://aucheval.tumblr.com/
# 3                       http://www.rickbayless.com/
# 4                               http://alsdeli.net/
# 5                  http://publicanqualitymeats.com/
# 6                                                 -
# 7                         http://acadiachicago.com/
# 8                  http://www.birchwoodkitchen.com/
# 9                         http://cemitaspuebla.com/
# 10                          http://nanaorganic.com/
# 11                             http://lulacafe.com/
# 12                   http://www.ricobenespizza.com/
# 13                           http://frognsnail.com/
# 14                http://crosbyskitchenchicago.com/
# 15                  http://www.longmanandeagle.com/
# 16                  http://www.bariitaliansubs.com/
# 17                           http://mannysdeli.com/
# 18                       http://www.eggysdiner.com/
# 19                  http://oldjerusalemchicago.com/
# 20                  http://hotchocolatechicago.com/
# 21                                                -
# 22                    http://www.dawalikitchen.com/
# 23                      http://bigjoneschicago.com/
# 24                        http://lapanechicago.com/
# 25                      http://pastoralartisan.com/
# 26                            http://maxs-deli.com/
# 27                    http://www.luckysandwich.com/
# 28                       http://cityprovisions.com/
# 29                    http://papascachesabroso.com/
# 30                                                -
# 31                       http://hannahsbretzel.com/
# 32                          http://lafournette.com/
# 33                        http://paramountroom.com/
# 34             http://meltsandwichshoppechicago.com
# 35                         http://www.floriole.com/
# 36                           http://firstslice.org/
# 37                       http://troquetchicago.com/
# 38                           http://grahamwich.com/
# 39                         http://saigonsisters.com
# 40                         http://rosaliasdeli.com/
# 41                         http://zhmarketcafe.com/
# 42                   http://www.themarkethouse.com/
# 43  http://www.jdvhotels.com/hotels/chicago/lincoln
# 44             http://marionstreetcheesemarket.com/
# 45                      http://cafecitochicago.com/
# 46                      http://chickpeaonthego.com/
# 47                     http://goddessandgrocer.com/
# 48                         http://eatmyzenwich.com/
# 49                   http://www.tonipatisserie.com/
# 50                        http://phoebesbakery.com/

# %%
# 2차 저장
df.to_csv('data/chicago_sandwiches_2012_v2.csv', sep = ',', encoding = 'UTF-8')

# %%
class ChicagoSandwichesCrawling:
    df = pd.DataFrame()
    
    def init(self, name='시카고샌드위치먹어야됨'):
        self.name = name
        
    def get_df(self):
        return self.df
    
    def set_df(self, df):
        self.df = df
        
    def read_file(self, file_name='data/chicago_sandwiches_2012.csv'):
        self.df = pd.read_csv(file_name, encoding='UTF-8', index_col='순위')
        
    def save_file(self, file_name='data/chicago_sandwiches_2012_v2.csv'):
        self.df.to_csv(file_name, sep=',', encoding='UTF-8')
        
    def ChiSdw_detail(self):
        
        Price = []; Address = []
        Phone = []; Hompage = []

        for link in tqdm_notebook(df['링크']):
            html = urlopen(link)
            soup = BeautifulSoup(html, 'lxml')

            p_tag = soup.find('p', 'addy')

            addy = p_tag.get_text().strip()

            # 홈페이지 링크 =============================== #
            if p_tag.find('a') is not None:
                tmp = p_tag.find('a')
                homepage = tmp['href']
            else:
                homepage = "-"

            # price : '$00.00' ============================ #
            re_price = re.search('\$\d{1,2}\.\d{0,2}[ .]?', addy)
            if re_price is not None:
                 price = re_price.group().strip()
            else: 
                 pass

            # phone : '000-000-0000' ====================== #
            re_phone = re.search('\d{3}[ -.]?\d{3}[ -.]?\d{4}', addy)
            if re_phone is not None:
                 phone = re_phone.group()
            else:
                 pass

            # addr: 정규식으로 하고 싶은데 안 돼요 ======== #
            removal = homepage.replace('http://', '')
            removal = removal.replace('www.', '')
            removal = removal.replace('/', '').strip()

            re_addr = addy.replace(phone, '')
            re_addr = re_addr.replace(price, '')
            re_addr = re_addr.replace(removal, '')

            if re_addr is not None:
                addr = re_addr.replace(',', '').strip()
            else:
                pass

            Price.append(price)
            Phone.append(phone)
            Address.append(addr)
            Hompage.append(homepage)

        self.df['가격'] = Price
        self.df['주소'] = Address
        self.df['전화번호'] = Phone
        self.df['홈페이지'] = Hompage

        print('샌드위치 먹으러 시카고 가야겠네...')

    def do_start(self):
        self.read_file()
        self.ChiSdw_detail()
        self.save_file()

# %%
crawler = ChicagoSandwichesCrawling()
crawler.do_start()
# Out:
# c:\users\samsung\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:24: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))
# 샌드위치 먹으러 시카고 가야겠네...

# %%
crawler.df.loc[1]
# Out:
# 카페명                                           Old Oak Tap
# 메뉴명                                                   BLT
# 링크      http://www.chicagomag.com/Chicago-Magazine/Nov...
# 가격                                                   $10.
# 주소                                   2109 W. Chicago Ave.
# 전화번호                                         773-772-0406
# 홈페이지                         http://www.theoldoaktap.com/
# Name: 1, dtype: object
